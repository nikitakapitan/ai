# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# %% [markdown]
# ### parse data

# %%
# df = pd.read_csv('')
features = df[:-1]
answers = df[-1]

X, y, X_tst, y_tst = train_test_split(features, answers, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-54ff34effc2e> in <module>()
#       1 # df = pd.read_csv('')
# ----> 2 features = df[:-1]
#       3 answers = df[-1]
#       4
#       5 X, y, Xtst, ytst = train_test_split()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### learn

# %% [markdown]
# classifiers methods:
#
# Pre-trained:
# - fit
#
# Post-trained:
# - predict
# - predict_proba

# %%
classif = LogisticRegression
classif = KNeighborsClassifier

# %%
regress = LinearRegression

# %%
classif.fit(X,y)
y_pred = classif.predict(X_tst)

# %% [markdown]
# ### check

# %% [markdown]
# accuracy_score(y_tst, y_pred)
